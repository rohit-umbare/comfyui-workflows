# %% [markdown]
# # Realtime image Generation using [ComfyUI](https://github.com/comfyanonymous/ComfyUI)
#
# ## How does this work? You can see it in action [**here**](https://github.com/rohit-umbare/comfyui-workflows/tree/main)
#
# ## 1. Run the following cell(shift+enter)
# ## 2. Wait for a minute, scroll down find link with .**moe** TLD
#
# ![link.jpg](attachment:1e780cfd-d401-4a1c-a9b2-9c9394c02e0c.jpg)
#
#
# while the link is loading, follow the last markdown

# %%
# !git clone https://github.com/comfyanonymous/ComfyUI.git
# %cd ComfyUI
# !pip -q install -r requirements.txt
# !pip -q install aria2
# !mamba install openssh -y
# !mkdir ~/.ssh/
# !touch ~/.ssh/known_hosts
# !ssh-keyscan -t rsa remote.moe >> ~/.ssh/known_hosts
# !rm /root/.ssh/id_rsa
# !ssh-keygen -t rsa -b 4096 -f /root/.ssh/id_rsa -q -N ""
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/stabilityai/sdxl-turbo/resolve/main/sd_xl_turbo_1.0_fp16.safetensors -d /kaggle/working/ComfyUI/models/checkpoints -o sdxl-turbo.safetensors
# !python /kaggle/working/ComfyUI/main.py & ssh -R 80:127.0.0.1:8188 -o StrictHostKeyChecking=no -i /root/.ssh/id_rsa remote.moe

# %% [markdown]
# #  **Steps for enabling real time image generation**
#
# ## 1 Download workflow (**.json** file) :  Download raw file
# ### Click [**here**](https://github.com/rohit-umbare/comfyui-workflows/blob/main/real_time_sdxl_turbo.json) to download workflow
# ![git.jpg](attachment:1e29121f-cf34-43a1-aa4d-b6b083d499a5.jpg)
#
#
# ## 2. Drag and drop downloaded **.json** file downloaded earlier to load workflow
#
# ![pastejason.jpg](attachment:94056254-d75f-442f-8dac-ec169a95179b.jpg)
#
# ### you can also use load option(on the right side of the workflow)
#
#
# ## 3. now change the que prompt setting, **extra options**->**auto que**->**change**
# ![Screenshot from 2024-02-18 05-58-45.png](attachment:e6f069f8-9287-48ed-9452-bd72b4634e00.png)
#
# ## 4. Now try to erase a comma or a word from the prewritten prompt and wait a few seconds until the model loads.
# ## You can now start generating real time images.
